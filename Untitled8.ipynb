# %% [markdown]
# <a href="https://colab.research.google.com/github/hans8854/test/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2 
from google.colab.patches import cv2_imshow

img = cv2.imread('IMG_1800.JPG')
# cv2_imshow(img)
print(img.shape)
img = cv2.resize(img,(int(img.shape[1]/10),int(img.shape[0]/10)))
# data = np.random.random((5, 5))
# print(data)
# plt.imshow(data, cmap='cool', interpolation='nearest')
# plt.show()
# Out:
# (3024, 4032, 3)

# %%
print(img.shape)
# cv2_imshow(img)
b,g,r = cv2.split(img)
print(r)
plt.imshow(r, cmap='cool', interpolation='nearest')
plt.show()
# Out:
# (302, 403, 3)
# [[  4   6   3 ... 135 135 138]
#  [  3  12   9 ... 151 153 151]
#  [  6   4   0 ... 171 176 173]
#  ...
#  [198 207 220 ... 195 193 195]
#  [187 198 192 ... 195 197 199]
#  [184 189 191 ... 197 198 195]]

# %%
print(g)
plt.imshow(g, cmap='cool', interpolation='nearest')
plt.show()
# Out:
# [[ 18  18  15 ... 147 146 149]
#  [ 14  23  21 ... 162 164 162]
#  [ 20  15   4 ... 183 188 185]
#  ...
#  [161 170 185 ... 206 204 206]
#  [152 163 157 ... 207 209 211]
#  [148 154 156 ... 208 210 207]]

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
plt.imshow(gray, cmap='cool', interpolation='nearest')
plt.show()
